# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# we will load the diabetes dataset and create its object 
diabetes = datasets.load_diabetes()

# %%
# As we are implementing SLR, we will be using only one feature as follows
X = diabetes.data[:, np.newaxis, 2]

# %%
# we need to split the data into training and testing sets as follows
X_train = X[:-30]
X_test = X[-30:]

# %%
y_train = diabetes.target[:-30]
y_test = diabetes.target[-30:]

# %%
# To train the model we need to create linear regression object as follows
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets as follows
regr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the testing set as follows
y_pred = regr.predict(X_test)

# %%
print('Coefficients: \n', regr.coef_)
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [941.43097333]
# Mean squared error: 3035.06
# Variance score: 0.41

# %%
plt.scatter(X_test, y_test, color = 'blue')
plt.plot(X_test, y_pred, color = 'red', linewidth = 3)
plt.xticks(())
plt.yticks(())
plt.show()
