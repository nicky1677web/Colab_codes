# %%
import sys 
sys.setrecursionlimit(10**6)

n=[387420489]
d=n[0]
count=1
i=0
moves =n[i]

def code1(n,count,i,d,moves):
    if(n[i]==1):
        print("0")
    elif(n[i]!=0 and count!=moves):
        if( n[i]%6==0 and int(n[i]/6)!=1):
            n[i]=int(n[i]/6)
            count=count+1
            code1(n,count,i,d,moves)
        elif(n[i]%6!=0):
            n[i]=n[i]*2
            count=count+1
            code1(n,count,i,d,moves)
        elif(int(n[i]/6)==1 or count<=moves):
            print("its",count)
    else:{
        print("its -1")
    }
   
code1(n,count,i,d,moves)
# Out:
# its 36

# %%
import sys
 
sys.setrecursionlimit(10**6)

n=[12345]
d=n[0]
count=1
i=0
def code1(n,count,i,d):
    
    """print("list is",n)
    print("count is",count)
    print("i is",i)"""
    if(n[i]%6==0):
       if(n[i]!=0 and count!=d):
           if((int(n[i]/6)!=1) and (int(n[i]/6)!=0)):
               n[i]=int(n[i]/6)
               #print(n[i]/6)
               #print("n[i] is",n[i])
               count=count+1
               #print("is",count)
               code1(n,count,i,d)
           elif(int(n[i]/6)==1):
               print("is",count)
            
            
    elif(n[i]%6!=0 and count!=d):
        n[i]=n[i]*2
        #print("n[i] is1",n[i])
        #print("count is",count)
        code1(n,count+1,i,d)
        
    elif(n[i]==1):
        print(0)
        
    elif(count==d or n[i]/6==1):
        print(-1)
    
    #print("count is",count)
            
    #print(n[i])
        
            
code1(n,count,i,d)
# Out:
# -1

# %%
import sys 
sys.setrecursionlimit(10**6)

def code1(n,count,i,d):
        
    if(n[i]%6==0):
       if(n[i]!=0 and count!=d and count!=1000):
           if((int(n[i]/6)!=1) and (int(n[i]/6)!=0)):
               n[i]=int(n[i]/6)
               count=count+1
               code1(n,count,i,d)
           elif(int(n[i]/6)==1 and i!=len(n)):
               print(count) 
               count=0
              #  code1(n,count,i+1,d)
            
    elif(n[i]%6!=0 and count!=d and count!=1000):
        n[i]=n[i]*2
        code1(n,count+1,i,d)
        
    elif(n[i]==1 and i!=len(n)):
        print(0)
        count=0
        # code1(n,count,i+1,d)
        
        
    elif(i!=len(n) and (count==d or n[i]/6==1 or count==1000)):
        print(-1)
        # count=0
        # code1(n,count,i+1,d)
  
# code1(n,count,i,d)


m = int(input("Enter number of elements : "))
  
# Below line read inputs from user using map() function 
n = list(map(int,input("\nEnter the numbers : ").strip().split()))[:m]
  
print("\nList is - ", n)


for zz in range(0,m):
  d=n[zz]
  count=1
  k=zz
  code1(n,count,zz,d)
# Out:
# Enter number of elements : 7
#
# Enter the numbers : 1 2 3 12 12345 15116544 387420489
#
# List is -  [1, 2, 3, 12, 12345, 15116544, 387420489]
# 0
# -1
# 2
# -1
# -1
# 12
# 36

# %%
 = int(input("Enter number of elements : "))
  
# Below line read inputs from user using map() function 
a = list(map(int,input("\nEnter the numbers : ").strip().split()))[:n]
  
print(a)
# Out:
# Enter number of elements : 7
#
# Enter the numbers : 1 2 3 12 12345 15116544 387420489
# [1, 2, 3, 12, 12345, 15116544, 387420489]
